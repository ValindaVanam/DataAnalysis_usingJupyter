# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('coursera-course-detail-data.csv')

# %%
dataset
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                        "Making" Progress Teach-Out
# 1              1         (Business Writing) الكتابة في مجال الأعمال
# 2              2  (Giving Helpful Feedback) إعطاء الملاحظات المفيدة
# 3              3    (Successful Presentation) العرض التقديمي الناجح
# 4              4                                 .Net平台下的软件开发技术毕业项目
# ...          ...                                                ...
# 3845        3845                                               None
# 3846        3846                                Drugs and the Brain
# 3847        3847                                               None
# 3848        3848                                               None
# 3849        3849                                               None
#
#                                                     Url Rating  \
# 0             https://coursera.org/learn/makingprogress   None
# ...

# %%
X = dataset.iloc[:, 0:3].values
y = dataset.iloc[:, 2].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-e2d62ce8fc4a> in <module>
#       3
#       4 sc = StandardScaler()
# ----> 5 X_train = sc.fit_transform(X_train)
#       6 X_test = sc.transform(X_test)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     637         # Reset internal state before fitting
#     638         self._reset()
# --> 639         return self.partial_fit(X, y)
#     640
# ...

# %%
#import the titanic data into a dataframe 

import pandas as pd
base_train_df =pd.read_csv('coursera-course-detail-data.csv')

#reviewed data and select only continuous features
train_df = base_train_df[['Name', 'Url','Rating', 'Difficulty', 'Tags']]
train_df.head()
# Out:
#                                                 Name  \
# 0                        "Making" Progress Teach-Out
# 1         (Business Writing) الكتابة في مجال الأعمال
# 2  (Giving Helpful Feedback) إعطاء الملاحظات المفيدة
# 3    (Successful Presentation) العرض التقديمي الناجح
# 4                                 .Net平台下的软件开发技术毕业项目
#
#                                                  Url Rating      Difficulty  \
# 0          https://coursera.org/learn/makingprogress   None  Beginner Level
# 1  https://coursera.org/learn/writing-for-busines...   None  Beginner Level
# 2             https://coursera.org/learn/feedback-ar    4.8            None
# 3  https://coursera.org/learn/presentation-skills-ar    4.9  Beginner Level
# 4  https://coursera.org/learn/net-ruanjian-kaifa-...   None            None
#
#                                             Tags
# 0  ['Social Sciences', 'Governance and Society']
# 1            ['Business', 'Business Essentials']
# ...
